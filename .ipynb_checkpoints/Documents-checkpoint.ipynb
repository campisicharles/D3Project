# %%
# Dependencies
import requests
import json
import pandas as pd
import numpy as np

# %%
# Save file path to variable
#envi_data = "../Data/environmental_impact_of_food.csv"

# %%
envi_pd = pd.read_csv('../Data/environmental_impact_of_food_resultsNU.csv')
envi_pd.head()
# Out:
#             Unnamed: 0 Nutr. Units / FU      Resampled, Randomized Data  \
# 0                  NaN              NaN  Land Use (m2/nutritional unit)
# 1              Product              NaN                        5th pctl
# 2  Wheat & Rye (Bread)              2.7                             0.4
# 3         Maize (Meal)              4.5                             0.2
# 4        Barley (Beer)                5                            0.04
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0        NaN        NaN        NaN        NaN        NaN
# 1  10th pctl       Mean     Median  90th pctl  95th pctl
# 2        0.4        1.4        1.0        2.9        3.7
# 3        0.3        0.7        0.4        1.3        2.0
# 4        0.1        0.2        0.2        0.5        0.6
#
#                                           Unnamed: 8 Unnamed: 9  ...  \
# 0  GHG Emissions (kg CO2eq/NU, IPCC 2013 incl CC ...        NaN  ...
# 1                                           5th pctl  10th pctl  ...
# 2                                                0.3        0.3  ...
# 3                                                0.1        0.2  ...
# 4                                                0.1        0.1  ...
#
#                                        Unnamed: 46 Unnamed: 47  \
# 0  GHG (kg CO2eq/FU, IPCC 2013 incl. CC feedbacks)         NaN
# 1                                              Min         Max
# 2                                              0.2        20.9
# 3                                              0.1        16.0
# 4                                              0.1         0.5
#
#                           Unnamed: 48 Unnamed: 49  \
# 0  Acid. (kg SO2eq/FU, CML2 Baseline)         NaN
# 1                                 Min         Max
# 2                                 1.3        12.5
# 3                                 0.6         5.6
# 4                                 1.0         7.7
#
#                             Unnamed: 50 Unnamed: 51      Unnamed: 52  \
# 0  Eutr. (kg PO43-eq/FU, CML2 Baseline)         NaN  Fresh W. (L/FU)
# 1                                   Min         Max              Min
# 2                                   0.1        28.9                0
# 3                                   0.2         4.6                0
# 4                                   0.2         2.5                1
#
#   Unnamed: 53         Unnamed: 54 Unnamed: 55
# 0         NaN  Strs. W. WU (L/FU)         NaN
# 1         Max                 Min         Max
# 2       3,243                   1     124,568
# 3       1,590                   0     101,983
# 4         114                   1       8,297
#
# [5 rows x 56 columns]

# %%
list(envi_pd)
# Out:
# ['Unnamed: 0',
#  'Nutr. Units / FU',
#  'Resampled, Randomized Data',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Unnamed: 29',
#  'Unnamed: 30',
#  'Unnamed: 31',
#  'Unnamed: 32',
#  'Unnamed: 33',
#  'Unnamed: 34',
#  'Unnamed: 35',
#  'Unnamed: 36',
#  'Unnamed: 37',
#  'Unnamed: 38',
#  'Unnamed: 39',
#  'Unnamed: 40',
#  'Unnamed: 41',
#  'Unnamed: 42',
#  'Unnamed: 43',
#  'Data Without Resampling or Randomization (original study data, after harmonizing methodology)',
#  'Unnamed: 45',
#  'Unnamed: 46',
#  'Unnamed: 47',
#  'Unnamed: 48',
#  'Unnamed: 49',
#  'Unnamed: 50',
#  'Unnamed: 51',
#  'Unnamed: 52',
#  'Unnamed: 53',
#  'Unnamed: 54',
#  'Unnamed: 55']

# %%
# Create new table
select_envi = envi_pd[["Unnamed: 0", "Nutr. Units / FU", "Unnamed: 5",
                           "Unnamed: 11", "Unnamed: 23", "Unnamed: 29", "Unnamed: 35"]]
select_envi.head()
# Out:
#             Unnamed: 0 Nutr. Units / FU Unnamed: 5 Unnamed: 11 Unnamed: 23  \
# 0                  NaN              NaN        NaN         NaN         NaN
# 1              Product              NaN     Median      Median      Median
# 2  Wheat & Rye (Bread)              2.7        1.0         0.5         5.0
# 3         Maize (Meal)              4.5        0.4         0.3         2.2
# 4        Barley (Beer)                5        0.2         0.2         1.2
#
#   Unnamed: 29 Unnamed: 35
# 0         NaN         NaN
# 1      Median      Median
# 2         2.0         157
# 3         0.5          10
# 4         0.4           1

# %%
rename = select_envi.rename(columns={"Unnamed: 0": "Product", "Unnamed: 5": "Land_Use_m2/nutritional unit","Unnamed: 11":"GHG_Emissions_kg_CO2eq/NU",
                          "Unnamed: 23":"GHG_Emissions_kg_SO2eq/NU", "Unnamed: 29" :"GHG_Emissions_kg_PO4eq/NU","Unnamed: 35":"Freshwater_Withdrawals_L/NU"})
rename.head()
# Out:
#                Product Nutr. Units / FU Land_Use_m2/nutritional unit  \
# 0                  NaN              NaN                          NaN
# 1              Product              NaN                       Median
# 2  Wheat & Rye (Bread)              2.7                          1.0
# 3         Maize (Meal)              4.5                          0.4
# 4        Barley (Beer)                5                          0.2
#
#   GHG_Emissions_kg_CO2eq/NU GHG_Emissions_kg_SO2eq/NU  \
# 0                       NaN                       NaN
# 1                    Median                    Median
# 2                       0.5                       5.0
# 3                       0.3                       2.2
# 4                       0.2                       1.2
#
#   GHG_Emissions_kg_PO4eq/NU Freshwater_Withdrawals_L/NU
# 0                       NaN                         NaN
# 1                    Median                      Median
# 2                       2.0                         157
# 3                       0.5                          10
# 4                       0.4                           1

# %%
clean_envi_data = rename.drop([rename.index[0] , rename.index[1]])
clean_envi_data.head()
# Out:
#                Product Nutr. Units / FU Land_Use_m2/nutritional unit  \
# 2  Wheat & Rye (Bread)              2.7                          1.0
# 3         Maize (Meal)              4.5                          0.4
# 4        Barley (Beer)                5                          0.2
# 5              Oatmeal              2.6                          2.9
# 6                 Rice              3.7                          0.6
#
#   GHG_Emissions_kg_CO2eq/NU GHG_Emissions_kg_SO2eq/NU  \
# 2                       0.5                       5.0
# 3                       0.3                       2.2
# 4                       0.2                       1.2
# 5                       1.0                       3.7
# 6                       1.0                       5.0
#
#   GHG_Emissions_kg_PO4eq/NU Freshwater_Withdrawals_L/NU
# 2                       2.0                         157
# 3                       0.5                          10
# 4                       0.4                           1
# 5                       3.8                         256
# 6                       2.5                         427

# %%
clean_envi = clean_envi_data.reset_index()
clean_envi.head()
# Out:
#    index              Product Nutr. Units / FU Land_Use_m2/nutritional unit  \
# 0      2  Wheat & Rye (Bread)              2.7                          1.0
# 1      3         Maize (Meal)              4.5                          0.4
# 2      4        Barley (Beer)                5                          0.2
# 3      5              Oatmeal              2.6                          2.9
# 4      6                 Rice              3.7                          0.6
#
#   GHG_Emissions_kg_CO2eq/NU GHG_Emissions_kg_SO2eq/NU  \
# 0                       0.5                       5.0
# 1                       0.3                       2.2
# 2                       0.2                       1.2
# 3                       1.0                       3.7
# 4                       1.0                       5.0
#
#   GHG_Emissions_kg_PO4eq/NU Freshwater_Withdrawals_L/NU
# 0                       2.0                         157
# 1                       0.5                          10
# 2                       0.4                           1
# 3                       3.8                         256
# 4                       2.5                         427

# %%
final_envi = clean_envi.dropna()

final_envi2 = final_envi.drop(['index'], axis=1)
final_envi2.head()
# Out:
#                Product Nutr. Units / FU Land_Use_m2/nutritional unit  \
# 0  Wheat & Rye (Bread)              2.7                          1.0
# 1         Maize (Meal)              4.5                          0.4
# 2        Barley (Beer)                5                          0.2
# 3              Oatmeal              2.6                          2.9
# 4                 Rice              3.7                          0.6
#
#   GHG_Emissions_kg_CO2eq/NU GHG_Emissions_kg_SO2eq/NU  \
# 0                       0.5                       5.0
# 1                       0.3                       2.2
# 2                       0.2                       1.2
# 3                       1.0                       3.7
# 4                       1.0                       5.0
#
#   GHG_Emissions_kg_PO4eq/NU Freshwater_Withdrawals_L/NU
# 0                       2.0                         157
# 1                       0.5                          10
# 2                       0.4                           1
# 3                       3.8                         256
# 4                       2.5                         427

# %%
final_envi2 = final_envi2.rename(columns={"Nutr. Units / FU": "NutrUnits", 
                                      "Land_Use_m2/nutritional unit": "LandUse",
                                      "GHG_Emissions_kg_CO2eq/NU": "CO2Emissions",
                                      "GHG_Emissions_kg_SO2eq/NU": "SO2Emissions",
                                      "GHG_Emissions_kg_PO4eq/NU": "PO4Emissions",
                                      "Freshwater_Withdrawals_L/NU": "FreshwaterWithdrawals"})

final_envi2.head()
# Out:
#                Product NutrUnits LandUse CO2Emissions SO2Emissions  \
# 0  Wheat & Rye (Bread)       2.7     1.0          0.5          5.0
# 1         Maize (Meal)       4.5     0.4          0.3          2.2
# 2        Barley (Beer)         5     0.2          0.2          1.2
# 3              Oatmeal       2.6     2.9          1.0          3.7
# 4                 Rice       3.7     0.6          1.0          5.0
#
#   PO4Emissions FreshwaterWithdrawals
# 0          2.0                   157
# 1          0.5                    10
# 2          0.4                     1
# 3          3.8                   256
# 4          2.5                   427

# %%
final_envi2.to_csv("/Data/clean_environment_data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-11-3b107fbfb7eb> in <module>
# ----> 1 final_envi2.to_csv("../Data/clean_environment_data.csv", index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     155             f, handles = _get_handle(self.path_or_buf, self.mode,
#     156                                      encoding=self.encoding,
# --> 157                                      compression=self.compression)
#     158             close = True
#     159
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     422         elif encoding:
#     423             # Python 3 and encoding
# --> 424             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     425         elif is_text:
#     426             # Python 3 and no explicit encoding
#
# PermissionError: [Errno 13] Permission denied: '../Data/clean_environment_data.csv'
